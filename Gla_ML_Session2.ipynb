# %% [markdown]
# <a href="https://colab.research.google.com/github/wizm0hit/Gla_ML_Session/blob/main/Gla_ML_Session2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
subjects = ["Python", "Math", "AI", "Data"]
print(subjects)
print(subjects[0])
print(subjects[-1])
# Out:
# ['Python', 'Math', 'AI', 'Data']
# Python
# Data

# %%
dic = {
    'college' : 'GLA',
    'class' : 'CB',
    'student' : 'Mohit'
}
dic["city"] = "Mathura"
dic['Gradings']=['A+', 'A' ,'B+' ,'B']

# %%
student1 = {
    'college' : 'GLA',
    'class' : 'CB',
    'student' : 'Alice',
    'city' : "Mathura",
    'Grade' : 'A+'
}

student2 = {
    'college' : 'GLA',
    'class' : 'CB',
    'student' : 'Iruma',
    'city' : "Mathura",
    'Grade' : 'A+'
}

student3 = {
    'college' : 'GLA',
    'class' : 'CB',
    'student' : 'ben',
    'city' : "Mathura",
    'Grade' : 'C'
}

student4 = {
    'college' : 'GLA',
    'class' : 'CB',
    'student' : 'chichi',
    'city' : "Mathura",
    'Grade' : 'B'
}
student5 = {
    'college' : 'GLA',
    'class' : 'CB',
    'student' : 'Mohit',
    'city' : "Mathura",
    'Grade' : 'A'
}

# %%
marks = 72

if marks>=80:
  print("Dinstiction")
elif marks >= 40 & marks < 80:
  print( 'Pass')
else:
  print("Fail")
# Out:
# Pass

# %%
age = int(input())
if age < 0:
  print('Invalid')
elif age < 13:
  print('Child')
elif age <= 19:
  print('teenager')
else:
  print('Adult')

# %%
student = [student1, student2, student3]
student1 = {
    'name' : 'Alice',
    'marks' : 90,
    'lab' : True,
    'attendence' : 90
}

student2 = {
    'name' : 'Brocoli',
    'marks' : 80,
    'lab' : True,
    'attendence' : 80
}

student3 = {
    'name' : 'Cabage',
    'marks' : 70,
    'lab' : False,
    'attendence' : 70
}

student4 = {
    'name' : 'Durian',
    'marks' : 60,
    'lab' : False,
    'attendence' : 90
}

student5 = {
    'name' : 'Eggplant',
    'marks' : 50,
    'lab' : False,
    'attendence' : 90
}


for student in student:
  if student['marks'] > 70:
    print('distinction')
  elif student['marks'] > 40:
    print('pass')
  else:
    print('fail')

for student in student:
  if not student['lab']:
    print('lab not assigned')
for student in student:
  if student['attendence'] < 70:
    print('low attendence')

# %%
def result(marks):
  if marks < 40:
    return 'Fail'
  else:
    return 'Pass'

marks = int(input())
print(result(marks))

# %% [markdown]
# # NumPY

# %%
import numpy as np

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-6fc979b4-a34b-4078-a55d-c92de1be6e98" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6fc979b4-a34b-4078-a55d-c92de1be6e98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('session4_dummy_students_data.csv')
print(df)
# Out:
#     student_id    name  age     city  math  science  english  \
# 0          101   Aarav   16   Mumbai    78       84       69
# 1          102    Diya   16    Delhi    91       88       94
# 2          103   Kabir   17  Mathura    55       61       58
# 3          104   Meera   16    Noida    72       79       81
# 4          105   Rohan   17   Mumbai    40       52       47
# 5          106    Sara   16    Delhi    88       93       90
# 6          107  Ishaan   17  Mathura    64       70       66
# 7          108  Ananya   16    Noida    95       92       89
# 8          109  Vivaan   17   Mumbai    48       57       51
# 9          110    Tara   16    Delhi    83       76       85
# 10         111   Arjun   17  Mathura    67       63       72
# 11         112   Nisha   16    Noida    74       81       79
# 12         113     Dev   17   Mumbai    35       45       42
# 13         114   Priya   16    Delhi    89       86       91
# ...

# %%
marks = df['science'].to_numpy()
print(marks)
print(type(marks))
print(marks.mean())
# Out:
# [84 88 61 79 52 93 70 92 57 76 63 81 45 86 54 90 69 85 49 73]
# <class 'numpy.ndarray'>
# 72.35

# %%
sci = df['science'].to_numpy()
math = df['math'].to_numpy()
eng = df['english'].to_numpy()
print((sci.sum() + math.sum() + eng.sum())/3)
# Out:
# 1427.0

# %%
# 3 filters
#1st filter top students whose avg is greater than 85
#2nd low attendence, less than 75
#3rd filter stduents from mathura

# %%
top_stu = df[df[['math', 'science', 'english']].mean(axis=1) > 85]
low_att = df[df['attendance_percent'] < 75]
mathura = df[df['city'] == 'Mathura']

# %%
print(top_stu)
print(low_att)
print(mathura)
# Out:
#     student_id    name  age   city  math  science  english  \
# 1          102    Diya   16  Delhi    91       88       94
# 5          106    Sara   16  Delhi    88       93       90
# 7          108  Ananya   16  Noida    95       92       89
# 13         114   Priya   16  Delhi    89       86       91
# 15         116    Riya   16  Noida    92       90       96
#
#     attendance_percent  study_hours_per_week  assignments_submitted  \
# 1                   96                    11                     10
# 5                   97                    10                     10
# 7                   94                    12                     10
# 13                  95                    10                     10
# 15                  98                    13                     10
#
#     final_project_score
# 1                    93
# 5                    95
# 7                    91
# 13                   92
# 15                   96
# ...

# %% [markdown]
# * Read session4_dummy_students. csv
# * Create an average column using math, science, and english.
# * Create a result column: Pass if average >= 40, otherwise Fail.
# * Print class average.
# * Print highest average and lowest average.
# * Print top student or students.
# * Print students with attendance below 75.
# * Print students who submitted fewer than 6 assignments.
# * Save final output as session4_student_report.csv.

# %%
df = pd.read_csv('session4_dummy_students_data.csv')

df['Average'] = df[['math', 'science', 'english']].mean(axis=1)

df['Result'] = ''
for i in range(len(df)):
  if df['Average'][i] >= 40:
    df['Result'][i] = 'Pass'
  else:
    df['Result'][i] = 'Fail'

print(df['Average'].mean())

print(df['Average'].max())
print(df['Average'].min())

print(df[df['Average'] == df['Average'].max()])

print(df[df['attendance_percent'] < 75])

print(df[df['assignments_submitted'] < 6])
# Out:
# 71.35000000000001
# 92.66666666666667
# 40.666666666666664
#     student_id  name  age   city  math  science  english  attendance_percent  \
# 15         116  Riya   16  Noida    92       90       96                  98
#
#     study_hours_per_week  assignments_submitted  final_project_score  \
# 15                    13                     10                   96
#
#       Average Result
# 15  92.666667   Pass
#     student_id    name  age     city  math  science  english  \
# 4          105   Rohan   17   Mumbai    40       52       47
# 8          109  Vivaan   17   Mumbai    48       57       51
# 12         113     Dev   17   Mumbai    35       45       42
# 18         119    Yash   17  Mathura    43       49       46
#
#     attendance_percent  study_hours_per_week  assignments_submitted  \
# 4                   68                     3                      5
# 8                   71                     4                      6
# ...
